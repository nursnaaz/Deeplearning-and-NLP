# %%
'''Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

path = get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=6,
          callbacks=[print_callback])
# Out:
# Using TensorFlow backend.
# corpus length: 600893
# total chars: 57
# nb sequences: 200285
# Vectorization...
# Build model...
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1044: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/6
# 200192/200285 [============================>.] - ETA: 0s - loss: 2.0025
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "ide, all self-confidence of spirit, it i"
# ide, all self-confidence of spirit, it is the mankind the strange the still and the still and the mankind and the such and the can of the most still and the science of the conscience of the still and the still and the science of the still and the disconting and the science of the such a philosophy and the straint of the straint and the still and the still the such the science of the stand and still and the strange of all the still and a
# ----- diversity: 0.5
# ----- Generating with seed: "ide, all self-confidence of spirit, it i"
# ide, all self-confidence of spirit, it is not the present of the all the devirious and power the morality and light forge their spetior of the was in the man herely sufferent of the despinitions the procance, and not in the schonder of all the as the par in the morality of the surperable of a sind as the stromby will the still pochaps and right of the fact of and a that the man in the side of last heart and the sperious for his mase the
# ----- diversity: 1.0
# ----- Generating with seed: "ide, all self-confidence of spirit, it i"
# ide, all self-confidence of spirit, it is new an imply, worker, the schepid and sympathore of the powaded as monglities, ok mankind and is of feelive
# of (andian.
# "ereis of waleshic serval that they confriveing
# gen
# it find. creation". to oht which met one more varieve:   in other one morality nanking estimal
# everythenbrute as the reficu any
# gait quest are--peacering, the criemity, the
# comparion, itself the reciail and physefuls: to the t
# ----- diversity: 1.2
# ----- Generating with seed: "ide, all self-confidence of spirit, it i"
# ide, all self-confidence of spirit, it iundeally,
# all leae gran onlyy--with dould those some us  he was
# now it--thal okly, consequently.", for vanding amaanness, which ie?--thus  w3le ny
# penseplaint
# will there, the gothing. a thingely.
#  fuble many but
#
#
# subphilorcandis; -remaincie withcred convict reperifiyicule. allsh for
# distinds? and oreedwance'sle chroacid and to mrom in and
# inigrutuve tho cauraweaw enob. gow catine been straidse
# h
# 200285/200285 [==============================] - 200s - loss: 2.0022
# Epoch 2/6
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.6402
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "ast that it is immoral to say that 'what"
# ast that it is immoral to say that 'what all the world and the paste of the fores of the spirit and the present and and the fored to the same in the world and the free in the sense of the sense of the such a perhaps and such a present of the power and the perion of the stand of the world and the string the world and the sense, and the morality of the sard and and the morality and the world and the world and the morality and the sense of
# ----- diversity: 0.5
# ----- Generating with seed: "ast that it is immoral to say that 'what"
# ast that it is immoral to say that 'what in the world of still supposity and the way and and spirit, by the been to a man the is in the replection of the because a dessicial althought and morality for the think and the science and a denerst of the the books
# ond itself and morality as a so the greature as a obtained to person the one's for in the soul to the have the for the to philosopher of also that a word and the
# mankind and the cons
# ----- diversity: 1.0
# ----- Generating with seed: "ast that it is immoral to say that 'what"
# ast that it is immoral to say that 'what not myself--perhapt to intelf
# conwinctom if not us so an
# prevace," not be themsnonatle boseed of firenerful other to the uncertaint aicy be to nake trusherity with it
# is to
# which itslengerate revolity or obsermand of the evenlely hn evence order indine) to the questive man
# that the nature dislikening
# consequently in
# the abter dusined, it. wonte, and that a be for that the our ort in heade be poss
# ----- diversity: 1.2
# ----- Generating with seed: "ast that it is immoral to say that 'what"
# ast that it is immoral to say that 'what-ncuds"ions,ost about the
# mositatorphess,
#
# them)s wonked ho
# kumenticaed ovpow for infeel aln philosophing and is therefore orasmed iven
# hrought ha very unbelopor, oo jay
# massarly
# is pessistion withey comes, formingly betayf will-liud unclar-great apilies pingrypthou pres
# it centerenturs that this iu
# science ears ise, may
# but adogine, lakepre conception efolity and base do not and
# his petitian and
# 200285/200285 [==============================] - 212s - loss: 1.6402
# Epoch 3/6
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.5525
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "ood, is the instinct of the herding huma"
# ood, is the instinct of the herding human is a subtle and and and the sees and and the man of the constitution of the consequently the constitution of the sense and it is all the sense of the sense of all the sense of the sense of the sense of the sense of all the subtle and the sense of the sense of the subtle and and and for the art in the sense of all the subtle and man of the sense of the possible and the sense of the sense and and
# ----- diversity: 0.5
# ----- Generating with seed: "ood, is the instinct of the herding huma"
# ood, is the instinct of the herding human self the
# constitution of the prosest a the act it is not also a destruction to he manure the make with such a the act the spirit" with the self and for the constraint to be the contemptiousness and a philosopher with proscend to the person that the conceptions of the soul and and and actually many the restrust no man intelle to the partious of the sense is
# he probated to find the through of the
# ----- diversity: 1.0
# ----- Generating with seed: "ood, is the instinct of the herding huma"
# ood, is the instinct of the herding human
# prompation it case (up
# all our tames. they hores of which agaquir to theirshed of oursout didder act in that certuunly, to wit itse is
# fight actunart--the usenty, they with constraintment for as them to
# inveruon recequarally when womst threater.
#
#
# 104. the
# baps for grafiman of mature and not our symb ink of the so must a upon philosophers eotricitation. a man is man: with felloped mojal mistrusi
# ----- diversity: 1.2
# ----- Generating with seed: "ood, is the instinct of the herding huma"
# ood, is the instinct of the herding humanity his experiently regarded
# as the staplivevations at a
# xoustrh oual, to more almost "have bas as othersuman!--existucates--kind of they causle, in,
# just alonator noe us at rects
# freedot in the
# value.: yan not suchlxe represiung fictur
# nature them, ikees ar
# cistell once of libstann of gain out acilation, is by difficultely a worshed, delorrenessn, wail be poseinglies; this fracc
# use us extraemar
# 200285/200285 [==============================] - 207s - loss: 1.5525
# Epoch 4/6
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.5062
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "nce for the bible has hitherto been main"
# nce for the bible has hitherto been maintainess and and the sentiment of the subjection of the subwless of the sentiment of the soul and substanding and the sentiment of the subliment of the soul and the sentiment of the particulated the philosophing the strength" the sentiment of the sense and it is the substance of the science of the probably in the strength of the sense--and the desire and and the power of the desire the subjection o
# ----- diversity: 0.5
# ----- Generating with seed: "nce for the bible has hitherto been main"
# nce for the bible has hitherto been mainer and so the free as the srelless and has so the and the individual to ascise of the courden the subbles the ancourdess of this power the increased the conduct of and as to see, and important and so of the desire and among it is not and and man. a so and substally and which interestrated pancy be of the delight to man in the world and something of the masters and does and subkise and the provicat
# ----- diversity: 1.0
# ----- Generating with seed: "nce for the bible has hitherto been main"
# nce for the bible has hitherto been mainnely to my this capmon of peateress, a philosopher bebutely and life.ly conscience blong
# syntimedntwly as--the deleint when gowmoelesty and also
# volued the ? the --a tlireung you dawging and developinc, the de-daccudusing sand to exceptions
# a theild. the knows the percais power, and in so man ofthing menines areafiness betragnem, he are
# stampthing has musuptiety, and pranct as
# resils
# sureml-passic
# ----- diversity: 1.2
# ----- Generating with seed: "nce for the bible has hitherto been main"
# nce for the bible has hitherto been main of solve experienc? into woute dearer
# individual catsking heattr-psysous: for the tol? he developenis easike out him
# is foods
# impragition.
# theredy.
# ? human instated one certainty and i othering lifetooneopous
# value cipments and eitoparitually
# ofcessity, history or
# gress for if life their
# =obquitily the by
# know man of
# us
# one, with ; a gal agtramd
# a thingly many
# re, olvand and, will fage
# had forat
# 200285/200285 [==============================] - 202s - loss: 1.5063
# Epoch 5/6
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.4759
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: " necessity. but this distinction is
# a de"
#  necessity. but this distinction is
# a destinent of the strange and an an an an an an an an an an an an an an an an an an a probably and the continuent of the person of the supersess of the constitution of the struggle the continuations of the more strange and the fact that is a man of the strumentant and an an an an an an an an an an an interpretess of the interpretess of the more profound and the struggle with the language and an an an
# ----- diversity: 0.5
# ----- Generating with seed: " necessity. but this distinction is
# a de"
#  necessity. but this distinction is
# a delight and an exception
# the distrust of such as it have women a religious demositions of the highest conditional the amotion, but the ancient and as a will connection of powerful of an an interpretation. the age there is not first the person of the rather all the origination and forter in the reality, the livery and the whole the soul and an any acciumned" the case of the most means of the highest
# ----- diversity: 1.0
# ----- Generating with seed: " necessity. but this distinction is
# a de"
#  necessity. but this distinction is
# a destined to becomiliby impossible only stapudsian poses it is the experatipdrient--above
# e plight insuveralies: the general wise time. but good acts sense and its grantity of conrend precisely age any knowledges giving, as hat distance of nay to but that is notively, of persistement and when behil gening unception, amoth in a truthful skiesse, and nare of all of contradianss--every wagnner at a reli
# ----- diversity: 1.2
# ----- Generating with seed: " necessity. but this distinction is
# a de"
#  necessity. but this distinction is
# a decews--it only moodhing too o"ther
# world?--kantly it of the exived such a sla-lithry of being wishnism, at thou alchatuling conbitit
# refreenaly. and a bypultion to shonly and frammently upen taste of a sidemel soul phanethic to
# him and duch  losing ords
# of unite" of all foremen germany glard
# candder sge the
# no denginoty, only, ideeration, ourlty, weaker wan andt--a
# nowperst
# defe fol trains must ita
# 200285/200285 [==============================] - 192s - loss: 1.4759
# Epoch 6/6
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.4546
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "
# according to balzac--i would venture to"
#
# according to balzac--i would venture to the sense of the present in the will something to the substance of the soul to the morality of the sense of the more the spectance of the sense of the contiments of the life the sense of the present to the morality in the sense of the power of the present to the present to the spirit and all the sense of the sense of the sense and sense of the former and the present to the spirituality of the sen
# ----- diversity: 0.5
# ----- Generating with seed: "
# according to balzac--i would venture to"
#
# according to balzac--i would venture to be a peating, and to in the any persons, it is not as the concenting to the spiritual, but and becomes neverthit is an its charanisticism, and the and concerned end spiritualizating contrae from the world and its consequently, and an all distrust of the means and against men of the egoost and the subjection and the freed calls of the suppose of society of the conception of the sense of old to a w
# ----- diversity: 1.0
# ----- Generating with seed: "
# according to balzac--i would venture to"
#
# according to balzac--i would venture to excount itself may europon a reac
# but upon in ethic is?
# in ir.--mentaneming philosopherly, that
# lave, use and conclations from theison, oftrance, bentaphing to the claster to can must be contrary marrance who has beent insolves, and cusion pacts, in the most transurmines
# in all slowers, things sympathar and so will ceetenty.--an continue live of then a ngamen very called indical ever truth of tho
# ----- diversity: 1.2
# ----- Generating with seed: "
# according to balzac--i would venture to"
#
# according to balzac--i would venture to transuspvier, bldod-coffurdy-necessity-i good--to geins
# of
# re, stono;out,
# those willing
# to but, to bode:--i
# very one fearry at too sympare--we gefless";ive
# in ocrues, and value, oversing and that he sharep's who
# timplies at the partingat value judgmenting, more dangers saish to them taking (himself hade the peosent, by us to loan, much drenmacte, any tort, once as unbecable wvecit, as thisuisch
#
# 200285/200285 [==============================] - 201s - loss: 1.4546
